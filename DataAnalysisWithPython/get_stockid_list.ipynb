# %%
##__________________________________________________environment setting_______________________________________________
import os
import sys
import numpy as np
from numpy.random import randn
from pandas import Series, DataFrame
import pandas as pd
import matplotlib.pyplot as plt

# %%
stockid_list = pd.read_csv('data/realstate.csv')

IDlist = []
for x in  stockid_list['stockid']:
    y = x[:6]
    IDlist.append(y)

IDlist
# Out:
# ['600376',
#  '601155',
#  '000926',
#  '600077',
#  '000062',
#  '600684',
#  '002344',
#  '000838',
#  '000615',
#  '000809',
#  '600510',
#  '600162',
#  '600622',
#  '600393',
#  '600466',
#  '600503',
#  '600515',
#  '600606',
#  '600565',
#  '600604',
#  '600621',
#  '600533',
#  '600555',
#  '600223',
#  '600215',
#  '600234',
#  '600225',
#  '600177',
#  '600173',
#  '600208',
#  '600185',
#  '600340',
#  '600325',
#  '600383',
#  '000006',
#  '600246',
#  '600239',
#  '600322',
#  '600266',
#  '600638',
#  '600773',
#  '600753',
#  '600791',
#  '600790',
#  '600745',
#  '600743',
#  '600748',
#  '600747',
#  '000005',
#  '600895',
#  '000002',
#  '601588',
#  '600823',
#  '600807',
#  '600890',
#  '600848',
#  '600663',
#  '600658',
#  '600675',
#  '600665',
#  '600641',
#  '600639',
#  '600657',
#  '600649',
#  '600732',
#  '600724',
#  '600736',
#  '600733',
#  '600692',
#  '600683',
#  '600716',
#  '600708',
#  '000608',
#  '000573',
#  '000616',
#  '000609',
#  '000540',
#  '000537',
#  '000567',
#  '000558',
#  '000671',
#  '000668',
#  '000718',
#  '000691',
#  '000631',
#  '000620',
#  '000667',
#  '000656',
#  '000043',
#  '000042',
#  '000056',
#  '000046',
#  '000031',
#  '000029',
#  '000040',
#  '000036',
#  '000514',
#  '000506',
#  '000534',
#  '000517',
#  '000402',
#  '000058',
#  '000505',
#  '000502',
#  '600048',
#  '600007',
#  '600053',
#  '600052',
#  '002244',
#  '002208',
#  '002305',
#  '002285',
#  '600133',
#  '600094',
#  '600159',
#  '600158',
#  '600067',
#  '600064',
#  '600082',
#  '000011',
#  '000918',
#  '000897',
#  '000931',
#  '000014',
#  '000736',
#  '000732',
#  '000863',
#  '000797',
#  '002077',
#  '002016',
#  '002146',
#  '002133',
#  '000979',
#  '000965',
#  '001979',
#  '000981']
